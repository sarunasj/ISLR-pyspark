# %% [markdown]
# # 4. Classification

# %%
from pyspark.sql import SparkSession
from pyspark import SparkContext

spark = SparkSession.builder.appName('classification').getOrCreate()
sc = SparkContext.getOrCreate()

import pyspark.sql.functions as F
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.regression import GeneralizedLinearRegression
from pyspark.ml.feature import VectorAssembler, VectorIndexer, StringIndexer, OneHotEncoder
from pyspark.ml import Pipeline
from pyspark.ml.regression import GeneralizedLinearRegression
from pyspark.mllib.evaluation import MulticlassMetrics

from utils import prepare_data, estimate_correlation_matrix, get_GLM_modelSummary, predict_binary_category_based_on_threshold

import pandas as pd

# %%
# %load_ext autoreload

# %% [markdown]
# ## *4.6.1 The Stock Market Data*

# %%
# -> Load Smarket dataset:

Smarket = spark.read.csv('data/Smarket.csv',header=True,inferSchema=True)

print('Smarket dataset:'); Smarket.show(5)
print('Data types:'); Smarket.printSchema()
# Out:
# Smarket dataset:
# +---+----+------+------+------+------+------+------+------+---------+
# |_c0|Year|  Lag1|  Lag2|  Lag3|  Lag4|  Lag5|Volume| Today|Direction|
# +---+----+------+------+------+------+------+------+------+---------+
# |  1|2001| 0.381|-0.192|-2.624|-1.055|  5.01|1.1913| 0.959|       Up|
# |  2|2001| 0.959| 0.381|-0.192|-2.624|-1.055|1.2965| 1.032|       Up|
# |  3|2001| 1.032| 0.959| 0.381|-0.192|-2.624|1.4112|-0.623|     Down|
# |  4|2001|-0.623| 1.032| 0.959| 0.381|-0.192| 1.276| 0.614|       Up|
# |  5|2001| 0.614|-0.623| 1.032| 0.959| 0.381|1.2057| 0.213|       Up|
# +---+----+------+------+------+------+------+------+------+---------+
# only showing top 5 rows
#
# Data types:
# root
#  |-- _c0: integer (nullable = true)
#  |-- Year: integer (nullable = true)
#  |-- Lag1: double (nullable = true)
#  |-- Lag2: double (nullable = true)
#  |-- Lag3: double (nullable = true)
#  |-- Lag4: double (nullable = true)
#  |-- Lag5: double (nullable = true)
#  |-- Volume: double (nullable = true)
#  |-- Today: double (nullable = true)
#  |-- Direction: string (nullable = true)

# %% [markdown]
# ## *4.6.2 Logistic Regression*

# %%
# -> Estimate Pearson's correlation matrix:

cols = ['Year', 'Lag1', 'Lag2', 'Lag3', 'Lag4', 'Lag5', 'Volume', 'Today']
estimate_correlation_matrix(Smarket, cols, method='pearson', round_decimals=2)
# Out:
# <style  type="text/css" >
#     #T_6b343f30_59f2_11e9_a812_07a3edf731cerow0_col0 {
#             background-color:  #b40426;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow0_col1 {
#             background-color:  #4b64d5;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow0_col2 {
#             background-color:  #4f69d9;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow0_col3 {
#             background-color:  #4f69d9;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow0_col4 {
#             background-color:  #5470de;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow0_col5 {
#             background-color:  #4b64d5;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow0_col6 {
#             background-color:  #ebd3c6;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow0_col7 {
#             background-color:  #4b64d5;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow1_col0 {
#             background-color:  #3b4cc0;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow1_col1 {
#             background-color:  #b40426;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow1_col2 {
#             background-color:  #3d50c3;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow1_col3 {
#             background-color:  #4358cb;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow1_col4 {
#             background-color:  #4961d2;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow1_col5 {
#             background-color:  #3f53c6;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow1_col6 {
#             background-color:  #5470de;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow1_col7 {
#             background-color:  #3b4cc0;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow2_col0 {
#             background-color:  #3b4cc0;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow2_col1 {
#             background-color:  #3b4cc0;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow2_col2 {
#             background-color:  #b40426;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow2_col3 {
#             background-color:  #3d50c3;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow2_col4 {
#             background-color:  #455cce;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow2_col5 {
#             background-color:  #4358cb;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow2_col6 {
#             background-color:  #3d50c3;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow2_col7 {
#             background-color:  #3f53c6;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow3_col0 {
#             background-color:  #3b4cc0;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow3_col1 {
#             background-color:  #3f53c6;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow3_col2 {
#             background-color:  #3d50c3;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow3_col3 {
#             background-color:  #b40426;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow3_col4 {
#             background-color:  #4358cb;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow3_col5 {
#             background-color:  #3d50c3;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow3_col6 {
#             background-color:  #3d50c3;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow3_col7 {
#             background-color:  #4358cb;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow4_col0 {
#             background-color:  #3d50c3;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow4_col1 {
#             background-color:  #4358cb;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow4_col2 {
#             background-color:  #4358cb;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow4_col3 {
#             background-color:  #3f53c6;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow4_col4 {
#             background-color:  #b40426;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow4_col5 {
#             background-color:  #3b4cc0;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow4_col6 {
#             background-color:  #3b4cc0;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow4_col7 {
#             background-color:  #3f53c6;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow5_col0 {
#             background-color:  #3b4cc0;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow5_col1 {
#             background-color:  #3f53c6;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow5_col2 {
#             background-color:  #455cce;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow5_col3 {
#             background-color:  #3f53c6;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow5_col4 {
#             background-color:  #3f53c6;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow5_col5 {
#             background-color:  #b40426;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow5_col6 {
#             background-color:  #4358cb;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow5_col7 {
#             background-color:  #3b4cc0;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow6_col0 {
#             background-color:  #e3d9d3;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow6_col1 {
#             background-color:  #4f69d9;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow6_col2 {
#             background-color:  #3b4cc0;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow6_col3 {
#             background-color:  #3b4cc0;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow6_col4 {
#             background-color:  #3b4cc0;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow6_col5 {
#             background-color:  #3d50c3;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow6_col6 {
#             background-color:  #b40426;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow6_col7 {
#             background-color:  #455cce;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow7_col0 {
#             background-color:  #3b4cc0;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow7_col1 {
#             background-color:  #3b4cc0;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow7_col2 {
#             background-color:  #4358cb;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow7_col3 {
#             background-color:  #455cce;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow7_col4 {
#             background-color:  #455cce;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow7_col5 {
#             background-color:  #3b4cc0;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow7_col6 {
#             background-color:  #4b64d5;
#         }    #T_6b343f30_59f2_11e9_a812_07a3edf731cerow7_col7 {
#             background-color:  #b40426;
#         }</style>
# <table id="T_6b343f30_59f2_11e9_a812_07a3edf731ce" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Year</th>
#         <th class="col_heading level0 col1" >Lag1</th>
#         <th class="col_heading level0 col2" >Lag2</th>
#         <th class="col_heading level0 col3" >Lag3</th>
#         <th class="col_heading level0 col4" >Lag4</th>
#         <th class="col_heading level0 col5" >Lag5</th>
#         <th class="col_heading level0 col6" >Volume</th>
#         <th class="col_heading level0 col7" >Today</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_6b343f30_59f2_11e9_a812_07a3edf731celevel0_row0" class="row_heading level0 row0" >Year</th>
#         <td id="T_6b343f30_59f2_11e9_a812_07a3edf731cerow0_col0" class="data row0 col0" >1</td>
#         <td id="T_6b343f30_59f2_11e9_a812_07a3edf731cerow0_col1" class="data row0 col1" >0.03</td>
#         <td id="T_6b343f30_59f2_11e9_a812_07a3edf731cerow0_col2" class="data row0 col2" >0.03</td>
#         <td id="T_6b343f30_59f2_11e9_a812_07a3edf731cerow0_col3" class="data row0 col3" >0.03</td>
#         <td id="T_6b343f30_59f2_11e9_a812_07a3edf731cerow0_col4" class="data row0 col4" >0.04</td>
#         <td id="T_6b343f30_59f2_11e9_a812_07a3edf731cerow0_col5" class="data row0 col5" >0.03</td>

# %% [markdown]
# ## 4.6.2. *Logistic Regression*

# %%
# -> Prepare the dataset

data = prepare_data(df = Smarket,
                    labelCol = 'Direction',
                    label_is_categorical = True,
                    categoricalCols = [],
                    continuousCols = ['Year',  'Lag1', 'Lag2', 'Lag3', 'Lag4', 'Lag5', 'Volume', 'Today']
                   )
print('Data:'); data.show(5)

# -> Define the model:

glr = GeneralizedLinearRegression(family="binomial", 
                                  link="Logit", 
                                  featuresCol='features', 
                                  labelCol='label')

# -> Fit the model:

model = glr.fit(data)

# -> Model's summary:

get_GLM_modelSummary(model)

# -> Predictions

predictions = predict_binary_category_based_on_threshold(data, model, threshold=0.5)
print('Predictions:'); predictions.show(5)

# -> Confusion matrix:

metrics = MulticlassMetrics(predictions.select('label','predicted_category').rdd)

print('Confusion Matrix:')
confusion_matrix = pd.DataFrame(metrics.confusionMatrix().toArray())
print(confusion_matrix)
print('Accuracy = {}'.format(metrics.accuracy))
# Out:
# Data:
# +---+----+------+------+------+------+------+------+------+---------+--------------------+-----+
# |_c0|Year|  Lag1|  Lag2|  Lag3|  Lag4|  Lag5|Volume| Today|Direction|            features|label|
# +---+----+------+------+------+------+------+------+------+---------+--------------------+-----+
# |  1|2001| 0.381|-0.192|-2.624|-1.055|  5.01|1.1913| 0.959|       Up|[2001.0,0.381,-0....|  0.0|
# |  2|2001| 0.959| 0.381|-0.192|-2.624|-1.055|1.2965| 1.032|       Up|[2001.0,0.959,0.3...|  0.0|
# |  3|2001| 1.032| 0.959| 0.381|-0.192|-2.624|1.4112|-0.623|     Down|[2001.0,1.032,0.9...|  1.0|
# |  4|2001|-0.623| 1.032| 0.959| 0.381|-0.192| 1.276| 0.614|       Up|[2001.0,-0.623,1....|  0.0|
# |  5|2001| 0.614|-0.623| 1.032| 0.959| 0.381|1.2057| 0.213|       Up|[2001.0,0.614,-0....|  0.0|
# +---+----+------+------+------+------+------+------+------+---------+--------------------+-----+
# only showing top 5 rows
#
# Results
# ## -------------------------------------------------
# ##  Estimate | Std.Error | t Values | P-value
# ## -18.656804  2137.8787   -0.009      0.993
# ##   9.350410  1150.3076    0.008      0.994
# ##  10.026750   643.7278    0.016      0.988
# ##  25.101352  1575.4694    0.016      0.987
# ##  -0.056218  2085.3658   -0.000      1.000
# ##   3.896766  2423.8676    0.002      0.999
# ## -10.577422  3450.0522   -0.003      0.998
# ## -2828.442595 42708.7541   -0.066      0.947
# ## 37385.948705 4278818.8481    0.009      0.993
#
# ## Dispersion: 1.00
# ## Null Deviance: 1731.17
# ## Residual Degree Of Freedom Null: 1249.00
# ## Residual Degree Of Freedom: 1241.00
# ## AIC: 18.00
# Predictions:
# +---+----+------+------+------+------+------+------+------+---------+--------------------+-----+------------------+------------------+
# |_c0|Year|  Lag1|  Lag2|  Lag3|  Lag4|  Lag5|Volume| Today|Direction|            features|label|        prediction|predicted_category|
# +---+----+------+------+------+------+------+------+------+---------+--------------------+-----+------------------+------------------+
# |  1|2001| 0.381|-0.192|-2.624|-1.055|  5.01|1.1913| 0.959|       Up|[2001.0,0.381,-0....|  0.0|           1.0E-16|               0.0|
# |  2|2001| 0.959| 0.381|-0.192|-2.624|-1.055|1.2965| 1.032|       Up|[2001.0,0.959,0.3...|  0.0|           1.0E-16|               0.0|
# |  3|2001| 1.032| 0.959| 0.381|-0.192|-2.624|1.4112|-0.623|     Down|[2001.0,1.032,0.9...|  1.0|0.9999999999999999|               1.0|
# |  4|2001|-0.623| 1.032| 0.959| 0.381|-0.192| 1.276| 0.614|       Up|[2001.0,-0.623,1....|  0.0|           1.0E-16|               0.0|
# |  5|2001| 0.614|-0.623| 1.032| 0.959| 0.381|1.2057| 0.213|       Up|[2001.0,0.614,-0....|  0.0|           1.0E-16|               0.0|
# +---+----+------+------+------+------+------+------+------+---------+--------------------+-----+------------------+------------------+
# only showing top 5 rows
#
# Confusion Matrix:
#        0      1
# 0  648.0    0.0
# 1    0.0  602.0
# Accuracy = 1.0

# %%
## -> Example with train and test samples

# -> Split into train and test samples:

train = data.filter(F.col('Year')<2005)
Smarket_2005 = data.filter(F.col('Year')>=2005)

# -> Define the model:

model = GeneralizedLinearRegression(family="binomial", link="Logit", featuresCol='features', labelCol='label')

# alternative way to define a logistic regression model:
# model = LogisticRegression(featuresCol='features', labelCol='label')


# -> Fit the model
model_fit = model.fit(train)

# -> Predictions 

train_predictions = predict_binary_category_based_on_threshold(train, model_fit, threshold=0.5)
print('Train sample predictions:'); train_predictions.show(5)

test_predictions = predict_binary_category_based_on_threshold(Smarket_2005, model_fit, threshold=0.5)
print('\nTrain sample predictions:'); train_predictions.show(5)


# -> Confusion matrices and estimated accuracy values for train and test samples:

print('Train sample confusion matrix:')
metrics = MulticlassMetrics(train_predictions.select('label','predicted_category').rdd)
train_confusion_matrix = pd.DataFrame(metrics.confusionMatrix().toArray())

print(train_confusion_matrix)
print('\nTrain sample accuracy = {:.3f}'.format(metrics.accuracy))

print('\nTrain sample confusion matrix:')
metrics = MulticlassMetrics(test_predictions.select('label','predicted_category').rdd)
test_confusion_matrix = pd.DataFrame(metrics.confusionMatrix().toArray())

print(test_confusion_matrix)
print('\nTest sample accuracy = {:.3f}'.format(metrics.accuracy))
# Out:
# Train sample predictions:
# +---+----+------+------+------+------+------+------+------+---------+--------------------+-----+------------------+------------------+
# |_c0|Year|  Lag1|  Lag2|  Lag3|  Lag4|  Lag5|Volume| Today|Direction|            features|label|        prediction|predicted_category|
# +---+----+------+------+------+------+------+------+------+---------+--------------------+-----+------------------+------------------+
# |  1|2001| 0.381|-0.192|-2.624|-1.055|  5.01|1.1913| 0.959|       Up|[2001.0,0.381,-0....|  0.0|           1.0E-16|               0.0|
# |  2|2001| 0.959| 0.381|-0.192|-2.624|-1.055|1.2965| 1.032|       Up|[2001.0,0.959,0.3...|  0.0|           1.0E-16|               0.0|
# |  3|2001| 1.032| 0.959| 0.381|-0.192|-2.624|1.4112|-0.623|     Down|[2001.0,1.032,0.9...|  1.0|0.9999999999999999|               1.0|
# |  4|2001|-0.623| 1.032| 0.959| 0.381|-0.192| 1.276| 0.614|       Up|[2001.0,-0.623,1....|  0.0|           1.0E-16|               0.0|
# |  5|2001| 0.614|-0.623| 1.032| 0.959| 0.381|1.2057| 0.213|       Up|[2001.0,0.614,-0....|  0.0|           1.0E-16|               0.0|
# +---+----+------+------+------+------+------+------+------+---------+--------------------+-----+------------------+------------------+
# only showing top 5 rows
#
#
# Train sample predictions:
# +---+----+------+------+------+------+------+------+------+---------+--------------------+-----+------------------+------------------+
# |_c0|Year|  Lag1|  Lag2|  Lag3|  Lag4|  Lag5|Volume| Today|Direction|            features|label|        prediction|predicted_category|
# +---+----+------+------+------+------+------+------+------+---------+--------------------+-----+------------------+------------------+
# |  1|2001| 0.381|-0.192|-2.624|-1.055|  5.01|1.1913| 0.959|       Up|[2001.0,0.381,-0....|  0.0|           1.0E-16|               0.0|
# |  2|2001| 0.959| 0.381|-0.192|-2.624|-1.055|1.2965| 1.032|       Up|[2001.0,0.959,0.3...|  0.0|           1.0E-16|               0.0|
# |  3|2001| 1.032| 0.959| 0.381|-0.192|-2.624|1.4112|-0.623|     Down|[2001.0,1.032,0.9...|  1.0|0.9999999999999999|               1.0|
# |  4|2001|-0.623| 1.032| 0.959| 0.381|-0.192| 1.276| 0.614|       Up|[2001.0,-0.623,1....|  0.0|           1.0E-16|               0.0|
# |  5|2001| 0.614|-0.623| 1.032| 0.959| 0.381|1.2057| 0.213|       Up|[2001.0,0.614,-0....|  0.0|           1.0E-16|               0.0|
# +---+----+------+------+------+------+------+------+------+---------+--------------------+-----+------------------+------------------+
# only showing top 5 rows
#
# Train sample confusion matrix:
#        0      1
# 0  507.0    0.0
# 1    0.0  491.0
#
# Train sample accuracy = 1.000
#
# Train sample confusion matrix:
#        0      1
# 0  141.0    1.0
# 1    0.0  110.0
#
# Test sample accuracy = 0.996

# %% [markdown]
# ## *4.6.3 Linear Discriminant Analysis*

# %% [raw]
# The model is not implement in MLLIB.

# %% [markdown]
# ## *4.6.4 Quadratic Discriminant Analysis*

# %% [raw]
# The model is not implement in MLLIB.

# %% [markdown]
# ## *4.6.5 K-Nearest Neighbors*

# %% [raw]
# The model is not implement in MLLIB.
